# %%
import pandas as pd
iris=pd.read_csv('iris.csv', delimiter=',')
iris.head
# Out:
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
iris.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 6      7            4.6           3.4            1.4           0.3
# 32    33            5.2           4.1            1.5           0.1
# 74    75            6.4           2.9            4.3           1.3
# 75    76            6.6           3.0            4.4           1.4
# 33    34            5.5           4.2            1.4           0.2
# 120  121            6.9           3.2            5.7           2.3
# 100  101            6.3           3.3            6.0           2.5
# 58    59            6.6           2.9            4.6           1.3
# 92    93            5.8           2.6            4.0           1.2
# 54    55            6.5           2.8            4.6           1.5
#
#              Species
# 6        Iris-setosa
# 32       Iris-setosa
# 74   Iris-versicolor
# 75   Iris-versicolor
# 33       Iris-setosa
# 120   Iris-virginica
# 100   Iris-virginica
# 58   Iris-versicolor
# 92   Iris-versicolor
# ...

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.groupby('Species').size()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
iris["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
sns.set_style("white")
sns.kdeplot(data=iris, x='SepalLengthCm', y="SepalWidthCm",hue="Species", fill=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.kdeplot(data=iris, x='PetalLengthCm', y="PetalWidthCm",hue="Species")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.kdeplot(data=iris, x='SepalLengthCm', y="PetalLengthCm",hue="Species", fill=True)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.kdeplot(data=iris, x='PetalWidthCm', y="SepalWidthCm",hue="Species")
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(data=iris, x='SepalLengthCm', y="SepalWidthCm")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.scatterplot(data=iris, x='PetalLengthCm', y="PetalWidthCm")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.histplot(data=iris, x="SepalLengthCm", color="red")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data=iris, x="PetalLengthCm", color="blue", kde=True)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(data=iris, x="SepalWidthCm", color="green", bins=5)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(data=iris, x="PetalWidthCm", color="red", hue="Species", multiple="stack")
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
sns.histplot(data=iris, x="SepalLengthCm", hue="Species", multiple="stack")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.pairplot(iris.drop(['Id'], axis = 1),  hue='Species', height=2)
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.countplot(x = "Species", data = iris)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.boxplot(x='SepalLengthCm',y='SepalWidthCm',data=iris ,palette='YlGnBu')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
iris.hist(figsize=(12,12),layout=(3,3),sharex=False)
# Out:
# array([[<Axes: title={'center': 'Id'}>,
#         <Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)
